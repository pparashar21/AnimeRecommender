# %%
import kaggle
import os
from dotenv import load_dotenv
import sys
from pathlib import Path
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
from anime_sensei.exception.handler import ExceptionHandler
from anime_sensei.constant import *
from anime_sensei.entity import config_entity
load_dotenv()
import tqdm


kaggle_username = os.getenv("KAGGLE_USERNAME")
kaggle_key = os.getenv("KAGGLE_KEY")

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter


file_path = "anime-dataset-2023.csv"

# Load the latest version
anime = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "dbdmobile/myanimelist-dataset",
  file_path,
)

# %%
anime
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#                              Other name    Score  \
# ...

# %%
import pandas as pd
ratings = pd.read_csv("/Users/pparashar21/Desktop/Projects/AnimeRecommender/Artifacts/Data_ingestion/Feature_store/Anime_Ratings.csv")
ratings
# Out:
#           user_id    Username  anime_id             Anime Title  rating
# 0               1       Xinil        21               One Piece       9
# 1               1       Xinil        48             .hack//Sign       7
# 2               1       Xinil       320                  A Kite       5
# 3               1       Xinil        49        Aa! Megami-sama!       8
# 4               1       Xinil       304  Aa! Megami-sama! Movie       8
# ...           ...         ...       ...                     ...     ...
# 24325186  1291087   Oblongata     10611                    R-15       3
# 24325187  1291087   Oblongata       174            Tenjou Tenge       6
# 24325188  1291097  JuunanaSai      1535              Death Note       9
# 24325189  1291097  JuunanaSai       226              Elfen Lied      10
# 24325190  1291097  JuunanaSai      8425                  Gosick      10
#
# [24325191 rows x 5 columns]

# %%
users = pd.read_csv("/Users/pparashar21/Desktop/Projects/AnimeRecommender/Artifacts/Data_ingestion/Feature_store/Anime_Users.csv")
users
# Out:
#          Mal ID    Username  Gender                   Birthday  \
# 0             1       Xinil    Male  1985-03-04T00:00:00+00:00
# 1             3     Aokaado    Male                        NaN
# 2             4     Crystal  Female                        NaN
# 3             9      Arcane     NaN                        NaN
# 4            18         Mad     NaN                        NaN
# ...         ...         ...     ...                        ...
# 731285  1291083      Dolopa     NaN                        NaN
# 731286  1291085  alenrobnik     NaN                        NaN
# 731287  1291087   Oblongata     NaN  1993-01-30T00:00:00+00:00
# 731288  1291091      Etnota     NaN                        NaN
# 731289  1291097  JuunanaSai  Female                        NaN
#
#                     Location                     Joined  Days Watched  \
# 0                 California  2004-11-05T00:00:00+00:00         142.3
# ...
